# %%
import tensorflow as tf
import random 
import numpy as np
import os
import cv2
#from tqdm import tqdm

import pickle 
from PIL import Image
from PIL import Image, ImageOps
import cv2
from PIL import ImageEnhance
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
class CNN():
    def __init__(self, num_input, num_classes, cnn_config):
        cnn = [c[0] for c in cnn_config]
        cnn_num_filters = [c[1] for c in cnn_config]
        max_pool_ksize = [c[2] for c in cnn_config]

        self.X = tf.placeholder(tf.float32,
                                [None, num_input], 
                                name="input_X")
        self.Y = tf.placeholder(tf.int32, [None, num_classes], name="input_Y")
        self.dropout_keep_prob = tf.placeholder(tf.float32, [], name="dense_dropout_keep_prob")
        self.cnn_dropout_rates = tf.placeholder(tf.float32, [len(cnn), ], name="cnn_dropout_keep_prob")

        Y = self.Y
        X = tf.expand_dims(self.X, -1)
        pool_out = X
        with tf.name_scope("Conv_part"):
            for idd, filter_size in enumerate(cnn):
                with tf.name_scope("L"+str(idd)):
                    conv_out = tf.layers.conv1d(
                        pool_out,
                        filters=cnn_num_filters[idd],
                        kernel_size=(int(filter_size)),
                        strides=1,
                        padding="SAME",
                        name="conv_out_"+str(idd),
                        activation=tf.nn.relu,
                        kernel_initializer=tf.contrib.layers.xavier_initializer(),
                        bias_initializer=tf.zeros_initializer
                    )
                    pool_out = tf.layers.max_pooling1d(
                        conv_out,
                        pool_size=(int(max_pool_ksize[idd])),
                        strides=1,
                        padding='SAME',
                        name="max_pool_"+str(idd)
                    )
                    pool_out = tf.nn.dropout(pool_out, self.cnn_dropout_rates[idd])

            flatten_pred_out = tf.contrib.layers.flatten(pool_out)
            self.logits = tf.layers.dense(flatten_pred_out, num_classes)

        self.prediction = tf.nn.softmax(self.logits, name="prediction")
        self.loss = tf.nn.softmax_cross_entropy_with_logits(logits=self.logits, labels=Y, name="loss")
        correct_pred = tf.equal(tf.argmax(self.prediction, 1), tf.argmax(Y, 1))
        self.accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name="accuracy")

# %%
class NetManager():
    def __init__(self, num_input, num_classes, learning_rate, training_data,test_data,
                 max_step_per_action=5,
                 bathc_size=30,
                 dropout_rate=0.85):

        self.num_input = num_input
        self.num_classes = num_classes
        self.learning_rate = learning_rate
        self.training_data = training_data

        self.max_step_per_action = max_step_per_action
        self.bathc_size = bathc_size
        self.dropout_rate = dropout_rate

    def get_reward(self, action, step, pre_acc):
        count=0
        action = [action[0][0][x:x+4] for x in range(0, len(action[0][0]), 4)]
        cnn_drop_rate = [c[3] for c in action]
        
        with tf.Graph().as_default() as g:
            with g.container('experiment'+str(step)):
                model = CNN(self.num_input, self.num_classes, action)
                loss_op = tf.reduce_mean(model.loss)
                optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
                train_op = optimizer.minimize(loss_op)

                with tf.Session() as train_sess:
                    init = tf.global_variables_initializer()
                    train_sess.run(init)

                    for step in range(self.max_step_per_action):
                        count=count+1
                        t,z=next_batch(self.bathc_size,training_data,count)
                        #batch_x, batch_y = self.mnist.train.next_batch(self.bathc_size)
                        feed = {model.X: t,
                                model.Y: z,
                                model.dropout_keep_prob: self.dropout_rate,
                                model.cnn_dropout_rates: cnn_drop_rate}
                        _ = train_sess.run(train_op, feed_dict=feed)

                        if step % 5 == 0:
                            # Calculate batch loss and accuracy
                            loss, acc = train_sess.run(
                                [loss_op, model.accuracy],
                                feed_dict={model.X: t,
                                           model.Y: z,
                                           model.dropout_keep_prob: 1.0,
                                           model.cnn_dropout_rates: [1.0]*len(cnn_drop_rate)})
                            with open('test_pickle.pkl', 'wb') as pickle_out:  
                                pickle.dump(loss, pickle_out)
                            with open('test_pickle1.pkl', 'wb') as pickle_out1:  
                                pickle.dump(acc, pickle_out1)
                                                                
                                
# Save the model
                            print("Step " + str(step) +
                                  ", Minibatch Loss= " + "{:.4f}".format(loss) +
                                  ", Current accuracy= " + "{:.3f}".format(acc))
                    X = []
                    y = []
                    for features,label in test_data:
                        X.append(features)
                        y.append(label)
                    #batch_x, batch_y = self.mnist.test.next_batch(10000)
                    loss, acc = train_sess.run(
                                [loss_op, model.accuracy],
                                feed_dict={model.X: X,
                                           model.Y: y,
                                           model.dropout_keep_prob: 1.0,
                                           model.cnn_dropout_rates: [1.0]*len(cnn_drop_rate)})
                    print("!!!!!!acc:", acc, pre_acc)
                    if acc - pre_acc <= 0.01:
                        return acc, acc 
                    else:
                        return 0.01, acc

# %%
class Reinforce():
    def __init__(self, sess, optimizer, policy_network, max_layers, global_step,
                 division_rate=100.0,
                 reg_param=0.001,
                 discount_factor=0.99,
                 exploration=0.3):
        self.sess = sess
        self.optimizer = optimizer
        self.policy_network = policy_network 
        self.division_rate = division_rate
        self.reg_param = reg_param
        self.discount_factor=discount_factor
        self.max_layers = max_layers
        self.global_step = global_step

        self.reward_buffer = []
        self.state_buffer = []

        self.create_variables()
        var_lists = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
        self.sess.run(tf.variables_initializer(var_lists))

    def get_action(self, state):
        return self.sess.run(self.predicted_action, {self.states: state})
        if random.random() < self.exploration:
            return np.array([[random.sample(range(1, 35), 4*self.max_layers)]])
        else:
            return self.sess.run(self.predicted_action, {self.states: state})

    def create_variables(self):
        with tf.name_scope("model_inputs"):
            # raw state representation
            self.states = tf.placeholder(tf.float32, [None, self.max_layers*4], name="states")

        with tf.name_scope("predict_actions"):
            # initialize policy network
            with tf.variable_scope("policy_network"):
                self.policy_outputs = self.policy_network(self.states, self.max_layers)
                print("outputs: ",self.policy_outputs)

            self.action_scores = tf.identity(self.policy_outputs, name="action_scores")

            self.predicted_action = tf.cast(tf.scalar_mul(self.division_rate, self.action_scores), tf.int32, name="predicted_action")
            print("action:",self.predicted_action)


        # regularization loss
        policy_network_variables = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="policy_network")

        # compute loss and gradients
        with tf.name_scope("compute_gradients"):
            # gradients for selecting action from policy network
            self.discounted_rewards = tf.placeholder(tf.float32, (None,), name="discounted_rewards")

            with tf.variable_scope("policy_network", reuse=True):
                self.logprobs = self.policy_network(self.states, self.max_layers)
                print("self.logprobs", self.logprobs)

            # compute policy loss and regularization loss
            self.cross_entropy_loss = tf.nn.softmax_cross_entropy_with_logits(logits=self.logprobs[:, -1, :], labels=self.states)
            self.pg_loss            = tf.reduce_mean(self.cross_entropy_loss)
            self.reg_loss           = tf.reduce_sum([tf.reduce_sum(tf.square(x)) for x in policy_network_variables]) # Regularization
            self.loss               = self.pg_loss + self.reg_param * self.reg_loss

            #compute gradients
            self.gradients = self.optimizer.compute_gradients(self.loss)
            
            # compute policy gradients
            for i, (grad, var) in enumerate(self.gradients):
                if grad is not None:
                    self.gradients[i] = (grad * self.discounted_rewards, var)

            # training update
            with tf.name_scope("train_policy_network"):
                # apply gradients to update policy network
                self.train_op = self.optimizer.apply_gradients(self.gradients, global_step=self.global_step)

    def storeRollout(self, state, reward):
        self.reward_buffer.append(reward)
        self.state_buffer.append(state[0])

    def train_step(self, steps_count):
        states = np.array(self.state_buffer[-steps_count:])/self.division_rate
        rewars = self.reward_buffer[-steps_count:]
        _, ls = self.sess.run([self.train_op, self.loss],
                     {self.states: states,
                      self.discounted_rewards: rewars})
        return ls

# %%
#from tensorflow.examples.tutorials.mnist import input_data

# %%
#input_data

# %%
'''
    Policy network is a main network for searching optimal architecture
    it uses NAS - Neural Architecture Search recurrent network cell.
    https://github.com/tensorflow/tensorflow/blob/r1.4/tensorflow/contrib/rnn/python/ops/rnn_cell.py#L1363
    Args:
        state: current state of required topology
        max_layers: maximum number of layers
    Returns:
        3-D tensor with new state (new topology)
'''
def policy_network(state, max_layers):
    with tf.name_scope("policy_network"):
        nas_cell = tf.contrib.rnn.NASCell(4*max_layers)
        outputs, state = tf.nn.dynamic_rnn(
            nas_cell,
            tf.expand_dims(state, -1),
            dtype=tf.float32
        )
        bias = tf.Variable([0.05]*4*max_layers)
        outputs = tf.nn.bias_add(outputs, bias)
        print("outputs: ",outputs[:, -1:, :])#,  tf.slice(outputs, [0, 4*max_layers-1, 0], [1, 1, 4*max_layers]))
        #return tf.slice(outputs, [0, 4*max_layers-1, 0], [1, 1, 4*max_layers]) # Returned last output of rnn
        return outputs[:, -1:, :]

# %%
def train(training_data,test_data):
    sess = tf.Session()
    global_step = tf.Variable(0, trainable=False)
    starter_learning_rate = 0.1
    learning_rate = tf.train.exponential_decay(0.99, global_step,
                                           500, 0.96, staircase=True)

    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate)

    reinforce = Reinforce(sess, optimizer, policy_network, 100, global_step)
    net_manager = NetManager(num_input=40000,
                             num_classes=2,
                             learning_rate=0.001,
                             training_data=training_data,
                             test_data=test_data,
                             bathc_size=300)

    MAX_EPISODES = 10
    step = 0
    state = np.array([[10.0, 128.0, 1.0, 1.0]*100], dtype=np.float32)
    pre_acc = 0.0
    total_rewards = 0
    for i_episode in range(MAX_EPISODES):       
        action = reinforce.get_action(state)
        print("ca:", action)
        if all(ai > 0 for ai in action[0][0]):
            reward, pre_acc = net_manager.get_reward(action, step, pre_acc)
            print("=====>", reward, pre_acc)
        else:
            reward = -1.0
        total_rewards += reward

        # In our sample action is equal state
        state = action[0]
        reinforce.storeRollout(state, reward)

        step += 1
        ls = reinforce.train_step(1)
        log_str = " episode:  "+str(i_episode)+" loss:  "+str(ls)+" last_state:  "+str(state)+" last_reward:  "+str(reward)+"\n"
        log = open("lg3.txt", "a+")
        log.write(log_str)
        log.close()
        print(log_str)

# %%
DATADIR = "/Users/sidgupta/Documents/mura/humerus"
DATADIR1 = "/Users/sidgupta/Documents/mura/humerus_v"

# %%
CATEGORIES = ["abnormal", "normal"]

# %%
IMG_SIZE=200
training_data = []
desired_size = 200


def create_training_data():
    for category in CATEGORIES:  # do dogs and cats

        path = os.path.join(DATADIR,category)  # create path to dogs and cats
        class_num = CATEGORIES.index(category)  # get the classification  (0 or a 1). 0=dog 1=cat
        if ((class_num)==1):
            t=[0,1]
        else:
            t=[1,0]
        
        for img in os.listdir(path):  # iterate over each image per dogs and cats
            im = Image.open(os.path.join(path,img))
            enhancer = ImageEnhance.Sharpness(im)
            img2=enhancer.enhance(2)
            img2 = img2.resize((200,200), Image.ANTIALIAS) 
            img2=img2.convert("L")
            img2 = image.img_to_array(img2)
            new_array = np.array(img2).reshape(40000)


            #new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            # resize to normalize data size
            #new_array = np.array(img2).reshape(40000)
            training_data.append([new_array,t ])  # add this to our training_data
        
            #except OSError as e:
            #    print("OSErrroBad img most likely", e, os.path.join(path,img))
            #except Exception as e:
            #    print("general exception", e, os.path.join(path,img))

create_training_data()

print(len(training_data))
# Out:
# 1272

# %%
training_data
# Out:
# [[array([51., 54., 55., ..., 52., 51., 53.], dtype=float32), [1, 0]],
#  [array([51., 52., 55., ..., 53., 53., 53.], dtype=float32), [1, 0]],
#  [array([159., 156., 153., ...,  29.,  28.,  29.], dtype=float32), [1, 0]],
#  [array([174., 157., 159., ...,  29.,  29.,  29.], dtype=float32), [1, 0]],
#  [array([35., 34., 35., ..., 19., 19., 20.], dtype=float32), [1, 0]],
#  [array([102., 100.,  95., ...,  38.,  37.,  36.], dtype=float32), [1, 0]],
#  [array([ 71.,  66.,  63., ...,  98.,  99., 100.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 10., 11.], dtype=float32), [1, 0]],
#  [array([ 59.,  70.,  60., ...,  87., 103.,  89.], dtype=float32), [1, 0]],
#  [array([81., 65., 59., ..., 44., 37.,  0.], dtype=float32), [1, 0]],
#  [array([53., 53., 52., ..., 55., 56., 55.], dtype=float32), [1, 0]],
#  [array([54., 54., 55., ..., 54., 55., 54.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([106., 116., 137., ...,  61.,  78., 106.], dtype=float32), [1, 0]],
#  [array([106., 119., 134., ...,  20.,  36.,  70.], dtype=float32), [1, 0]],
#  [array([117., 110.,  82., ...,  30.,  36.,  52.], dtype=float32), [1, 0]],
#  [array([116., 108.,  71., ...,  28.,  36.,  54.], dtype=float32), [1, 0]],
#  [array([51., 51., 50., ..., 50., 50., 49.], dtype=float32), [1, 0]],
#  [array([54., 55., 53., ..., 46., 46., 47.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([105., 105., 105., ...,  86.,  87.,  88.], dtype=float32), [1, 0]],
#  [array([245., 244., 244., ..., 246., 247., 247.], dtype=float32), [1, 0]],
#  [array([48., 41., 40., ..., 68., 66., 58.], dtype=float32), [1, 0]],
#  [array([110., 148., 110., ..., 172., 189., 143.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 2.,  2.,  1., ..., 48., 48., 47.], dtype=float32), [1, 0]],
#  [array([58., 84., 68., ...,  0.,  0.,  0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([202., 202., 202., ..., 196., 197., 197.], dtype=float32), [1, 0]],
#  [array([55., 55., 55., ..., 57., 57., 57.], dtype=float32), [1, 0]],
#  [array([56., 56., 56., ..., 56., 56., 56.], dtype=float32), [1, 0]],
#  [array([  8.,   7.,   7., ..., 113., 113., 113.], dtype=float32), [1, 0]],
#  [array([ 7.,  7.,  7., ...,  9.,  9., 10.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([93., 91., 90., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([10.,  8.,  8., ...,  9.,  9., 10.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([88., 82., 76., ...,  0.,  0.,  0.], dtype=float32), [1, 0]],
#  [array([75., 70., 71., ..., 74., 72., 74.], dtype=float32), [1, 0]],
#  [array([4., 4., 4., ..., 5., 5., 4.], dtype=float32), [1, 0]],
#  [array([4., 3., 4., ..., 4., 4., 4.], dtype=float32), [1, 0]],
#  [array([51., 51., 50., ..., 34., 36., 36.], dtype=float32), [1, 0]],
#  [array([47., 46., 45., ..., 44., 44., 44.], dtype=float32), [1, 0]],
#  [array([56., 57., 56., ..., 55., 54., 54.], dtype=float32), [1, 0]],
#  [array([56., 55., 56., ..., 58., 58., 58.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([217., 217., 217., ..., 234., 233., 233.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([58., 57., 57., ..., 59., 59., 60.], dtype=float32), [1, 0]],
#  [array([198., 198., 197., ..., 205., 205., 205.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 44., 50., 54.], dtype=float32), [1, 0]],
#  [array([10.,  9., 10., ..., 10., 10.,  9.], dtype=float32), [1, 0]],
#  [array([11., 12., 11., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([11., 11., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([5., 5., 5., ..., 4., 4., 5.], dtype=float32), [1, 0]],
#  [array([5., 4., 5., ..., 4., 5., 5.], dtype=float32), [1, 0]],
#  [array([ 9.,  8.,  9., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([9., 8., 8., ..., 4., 3., 4.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([32., 32., 31., ..., 31., 32., 30.], dtype=float32), [1, 0]],
#  [array([30., 31., 30., ..., 28., 29., 28.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([9., 7., 8., ..., 9., 8., 8.], dtype=float32), [1, 0]],
#  [array([4., 5., 4., ..., 5., 5., 5.], dtype=float32), [1, 0]],
#  [array([82., 84., 94., ..., 55., 55., 56.], dtype=float32), [1, 0]],
#  [array([58., 52., 47., ...,  0.,  1.,  0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([74., 83., 67., ...,  1.,  1.,  2.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([2., 3., 2., ..., 2., 2., 2.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 90., 91., 91.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 83., 101.,  88., ...,  99., 101.,  80.], dtype=float32), [1, 0]],
#  [array([52., 51., 50., ..., 76., 66., 61.], dtype=float32), [1, 0]],
#  [array([100.,  96.,  95., ...,  39.,  39.,  39.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([57., 57., 58., ..., 56., 57., 58.], dtype=float32), [1, 0]],
#  [array([59., 58., 58., ..., 54., 55., 55.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([6., 6., 5., ..., 7., 7., 7.], dtype=float32), [1, 0]],
#  [array([55., 57., 58., ..., 63., 62., 63.], dtype=float32), [1, 0]],
#  [array([  6.,   5.,   5., ..., 154., 161., 159.], dtype=float32), [1, 0]],
#  [array([ 40.,  40.,  39., ..., 210., 210., 210.], dtype=float32), [1, 0]],
#  [array([141., 142., 141., ..., 251., 251., 251.], dtype=float32), [1, 0]],
#  [array([134., 133., 132., ...,   3.,   3.,   3.], dtype=float32), [1, 0]],
#  [array([162., 160., 160., ..., 182., 182., 186.], dtype=float32), [1, 0]],
#  [array([149., 147., 147., ..., 159., 161., 157.], dtype=float32), [1, 0]],
#  [array([91., 87., 86., ..., 90., 91., 92.], dtype=float32), [1, 0]],
#  [array([67., 67., 67., ..., 68., 70., 70.], dtype=float32), [1, 0]],
#  [array([148., 148., 148., ...,  66.,  66.,  65.], dtype=float32), [1, 0]],
#  [array([204., 198., 201., ..., 173., 190., 195.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11., 11., 11., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([11., 10., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([11., 10.,  9., ...,  8.,  8.,  8.], dtype=float32), [1, 0]],
#  [array([10., 11., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([10.,  9., 10., ...,  9.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([145., 168., 183., ..., 102., 100.,  99.], dtype=float32), [1, 0]],
#  [array([46., 48., 48., ..., 49., 50., 52.], dtype=float32), [1, 0]],
#  [array([ 86.,  57.,  40., ..., 106., 107., 107.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ...,  4., 31., 37.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([9., 9., 9., ..., 8., 9., 9.], dtype=float32), [1, 0]],
#  [array([7., 8., 7., ..., 9., 9., 8.], dtype=float32), [1, 0]],
#  [array([127., 125., 125., ..., 204., 204., 206.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([123., 121., 121., ..., 137., 126., 128.], dtype=float32), [1, 0]],
#  [array([112., 115., 112., ...,  97.,  92., 101.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([5., 5., 4., ..., 6., 6., 6.], dtype=float32), [1, 0]],
#  [array([6., 6., 6., ..., 7., 6., 6.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([34., 32., 34., ..., 32., 32., 33.], dtype=float32), [1, 0]],
#  [array([168., 167., 167., ..., 166., 164., 168.], dtype=float32), [1, 0]],
#  [array([89., 90., 91., ..., 14., 15., 16.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ...,  0.,  3.,  3.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([55., 51., 51., ..., 39., 36., 41.], dtype=float32), [1, 0]],
#  [array([33., 43., 41., ..., 59., 54., 55.], dtype=float32), [1, 0]],
#  [array([44., 35., 35., ..., 40., 48., 42.], dtype=float32), [1, 0]],
#  [array([41., 42., 42., ..., 19., 19., 17.], dtype=float32), [1, 0]],
#  [array([34., 35., 34., ..., 23., 50., 52.], dtype=float32), [1, 0]],
#  [array([8., 8., 7., ..., 8., 8., 9.], dtype=float32), [1, 0]],
#  [array([246., 247., 247., ..., 245., 245., 244.], dtype=float32), [1, 0]],
#  [array([4., 4., 4., ..., 4., 4., 5.], dtype=float32), [1, 0]],
#  [array([  7.,   7.,   8., ..., 176., 174., 171.], dtype=float32), [1, 0]],
#  [array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), [1, 0]],
#  [array([ 61.,  82.,  87., ..., 130., 136.,  92.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([49., 47., 47., ...,  0.,  1.,  2.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 60.,  63.,  66., ..., 102., 101., 101.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([118., 106., 101., ..., 166., 172., 177.], dtype=float32), [1, 0]],
#  [array([57., 57., 56., ..., 72., 70., 74.], dtype=float32), [1, 0]],
#  [array([102., 110., 108., ..., 137., 139., 142.], dtype=float32), [1, 0]],
#  [array([114., 103.,  98., ..., 134., 137., 140.], dtype=float32), [1, 0]],
#  [array([111., 114., 114., ...,  93.,  94.,  95.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([111., 112., 112., ...,  77.,  79.,  81.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 11., 11., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 17., 17., 17.], dtype=float32), [1, 0]],
#  [array([198., 197., 198., ..., 196., 197., 195.], dtype=float32), [1, 0]],
#  [array([52., 52., 53., ..., 57., 57., 56.], dtype=float32), [1, 0]],
#  [array([202., 203., 203., ..., 211., 212., 211.], dtype=float32), [1, 0]],
#  [array([4., 3., 4., ..., 4., 5., 5.], dtype=float32), [1, 0]],
#  [array([3., 3., 4., ..., 3., 4., 4.], dtype=float32), [1, 0]],
#  [array([ 31.,  31.,  31., ..., 160., 158., 160.], dtype=float32), [1, 0]],
#  [array([37., 37., 37., ..., 37., 37., 36.], dtype=float32), [1, 0]],
#  [array([50., 50., 50., ..., 55., 55., 55.], dtype=float32), [1, 0]],
#  [array([123., 122., 125., ..., 111., 111., 111.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([57., 56., 56., ..., 54., 55., 57.], dtype=float32), [1, 0]],
#  [array([56., 56., 56., ..., 54., 55., 55.], dtype=float32), [1, 0]],
#  [array([56., 56., 55., ..., 52., 51., 52.], dtype=float32), [1, 0]],
#  [array([7., 6., 6., ..., 1., 1., 1.], dtype=float32), [1, 0]],
#  [array([ 3.,  3.,  4., ..., 10.,  8., 10.], dtype=float32), [1, 0]],
#  [array([62., 60., 60., ...,  7.,  8.,  8.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), [1, 0]],
#  [array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  8., ..., 69., 67., 66.], dtype=float32), [1, 0]],
#  [array([62., 59., 57., ..., 10., 13., 21.], dtype=float32), [1, 0]],
#  [array([131., 124., 123., ...,  85.,  81., 101.], dtype=float32), [1, 0]],
#  [array([ 92.,  89.,  87., ..., 105., 104., 106.], dtype=float32), [1, 0]],
#  [array([107., 103., 102., ...,  80.,  80.,  85.], dtype=float32), [1, 0]],
#  [array([59., 57., 57., ..., 59., 59., 58.], dtype=float32), [1, 0]],
#  [array([56., 55., 56., ..., 57., 57., 56.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([32., 32., 32., ..., 33., 30., 31.], dtype=float32), [1, 0]],
#  [array([21., 25., 25., ..., 27., 27., 27.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([54., 54., 54., ..., 47., 47., 48.], dtype=float32), [1, 0]],
#  [array([54., 53., 54., ..., 57., 57., 57.], dtype=float32), [1, 0]],
#  [array([63., 68., 54., ...,  1.,  2., 11.], dtype=float32), [1, 0]],
#  [array([77., 87., 75., ..., 45., 56., 45.], dtype=float32), [1, 0]],
#  [array([110.,  98.,  89., ...,   0.,   0.,   0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([33., 33., 35., ..., 33., 33., 31.], dtype=float32), [1, 0]],
#  [array([205., 210., 209., ...,  87.,  87.,  86.], dtype=float32), [1, 0]],
#  [array([211., 243., 216., ...,   2.,   3.,  62.], dtype=float32), [1, 0]],
#  [array([84., 92., 73., ..., 13., 14., 13.], dtype=float32), [1, 0]],
#  [array([52., 69., 64., ..., 20., 22., 22.], dtype=float32), [1, 0]],
#  [array([5., 5., 5., ..., 8., 7., 7.], dtype=float32), [1, 0]],
#  [array([ 32.,  30.,  31., ..., 151., 150., 151.], dtype=float32), [1, 0]],
#  [array([31., 29., 29., ..., 29., 28., 27.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([84., 83., 83., ..., 62., 66., 70.], dtype=float32), [1, 0]],
#  [array([50., 49., 48., ..., 51., 51., 51.], dtype=float32), [1, 0]],
#  [array([31., 21., 16., ..., 40., 40., 40.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 58., 59., 57.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 98.,  99.,  98., ..., 106., 105., 106.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([2., 3., 3., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([7., 7., 8., ..., 7., 7., 7.], dtype=float32), [1, 0]],
#  [array([10.,  9., 10., ...,  2.,  2.,  2.], dtype=float32), [1, 0]],
#  [array([34., 31., 31., ...,  4.,  3.,  4.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([54., 53., 54., ..., 54., 55., 53.], dtype=float32), [1, 0]],
#  [array([52., 51., 51., ..., 58., 58., 58.], dtype=float32), [1, 0]],
#  [array([4., 4., 4., ..., 4., 4., 4.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([6., 5., 5., ..., 5., 5., 6.], dtype=float32), [1, 0]],
#  [array([9., 8., 9., ..., 9., 8., 9.], dtype=float32), [1, 0]],
#  [array([133., 132., 132., ...,   8.,   8.,   8.], dtype=float32), [1, 0]],
#  [array([124., 123., 123., ...,  93.,  91.,  90.], dtype=float32), [1, 0]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [1, 0]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([113., 116., 117., ..., 140., 141., 152.], dtype=float32), [1, 0]],
#  [array([155., 149., 150., ...,  18.,  12.,  66.], dtype=float32), [1, 0]],
#  [array([  6.,   6.,   6., ..., 116., 110., 101.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 8.,  8.,  8., ..., 76., 78., 80.], dtype=float32), [1, 0]],
#  [array([8., 8., 7., ..., 7., 8., 7.], dtype=float32), [1, 0]],
#  [array([8., 8., 8., ..., 7., 7., 7.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([116.,  93.,  78., ..., 193., 193., 193.], dtype=float32), [1, 0]],
#  [array([ 82.,  75.,  72., ..., 203., 200., 200.], dtype=float32), [1, 0]],
#  [array([57., 57., 56., ..., 52., 52., 53.], dtype=float32), [1, 0]],
#  [array([57., 57., 57., ..., 54., 53., 52.], dtype=float32), [1, 0]],
#  [array([53., 54., 56., ..., 48., 48., 48.], dtype=float32), [1, 0]],
#  [array([198., 199., 197., ..., 200., 201., 201.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([14., 25., 38., ...,  8.,  7.,  9.], dtype=float32), [1, 0]],
#  [array([11., 11., 10., ...,  9.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([11., 10.,  9., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  9., ..., 76., 75., 74.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 43., 45., 11.], dtype=float32), [1, 0]],
#  [array([73., 91., 65., ..., 56., 96., 98.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([9., 9., 8., ..., 9., 8., 9.], dtype=float32), [1, 0]],
#  [array([11., 11., 11., ..., 12., 11., 11.], dtype=float32), [1, 0]],
#  [array([11., 11., 10., ..., 10., 11., 10.], dtype=float32), [1, 0]],
#  [array([11., 10., 11., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([152., 151., 149., ..., 143., 142., 149.], dtype=float32), [1, 0]],
#  [array([59., 55., 53., ..., 18., 18., 18.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  9., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([104., 101., 103., ...,  10.,  10.,  10.], dtype=float32), [1, 0]],
#  [array([ 85.,  85.,  85., ..., 101., 100., 100.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11., 11., 10., ..., 13., 13., 13.], dtype=float32), [1, 0]],
#  [array([ 4.,  4.,  4., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([144., 136., 143., ..., 155., 156., 155.], dtype=float32), [1, 0]],
#  [array([ 86.,  79.,  79., ..., 163., 164., 162.], dtype=float32), [1, 0]],
#  [array([  0.,   0.,   0., ..., 113., 126.,  83.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 86., 86., 83.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([102., 103., 113., ...,  50.,  49.,  48.], dtype=float32), [1, 0]],
#  [array([14.,  3.,  0., ...,  8.,  8.,  8.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  8., ..., 11., 11., 10.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([29., 29., 29., ..., 30., 29., 29.], dtype=float32), [1, 0]],
#  [array([33., 32., 32., ..., 31., 30., 31.], dtype=float32), [1, 0]],
#  [array([36., 35., 33., ..., 33., 32., 33.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([63., 62., 62., ..., 21., 14., 16.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([118., 115., 114., ..., 100., 101., 100.], dtype=float32), [1, 0]],
#  [array([155., 155., 155., ..., 162., 164., 164.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11., 10.,  9., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([56., 38., 14., ..., 62., 63., 65.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 53., 54., 51.], dtype=float32), [1, 0]],
#  [array([10.,  9.,  9., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 97., 92., 87.], dtype=float32), [1, 0]],
#  [array([67., 67., 66., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([119., 119., 117., ...,   7.,   7.,   7.], dtype=float32), [1, 0]],
#  [array([10.,  9., 10., ...,  9.,  9., 10.], dtype=float32), [1, 0]],
#  [array([55., 54., 55., ..., 54., 54., 53.], dtype=float32), [1, 0]],
#  [array([52., 52., 50., ..., 54., 54., 54.], dtype=float32), [1, 0]],
#  [array([4., 4., 4., ..., 4., 4., 3.], dtype=float32), [1, 0]],
#  [array([132., 135., 132., ...,   9.,   9.,   9.], dtype=float32), [1, 0]],
#  [array([117., 117., 117., ...,  10.,  11.,  11.], dtype=float32), [1, 0]],
#  [array([47., 48., 52., ..., 45., 44., 43.], dtype=float32), [1, 0]],
#  [array([51., 51., 55., ..., 48., 47., 47.], dtype=float32), [1, 0]],
#  [array([ 83., 118.,  91., ...,  54.,  75.,  81.], dtype=float32), [1, 0]],
#  [array([119., 119., 119., ...,  82.,  83.,  84.], dtype=float32), [1, 0]],
#  [array([201., 201., 201., ..., 200., 198., 199.], dtype=float32), [1, 0]],
#  [array([52., 52., 52., ..., 49., 50., 50.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([253., 253., 253., ..., 253., 253., 253.], dtype=float32), [1, 0]],
#  [array([253., 253., 253., ..., 253., 253., 253.], dtype=float32), [1, 0]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10.,  9., 10., ..., 10.,  9., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 18., ..., 17., 27., 58.], dtype=float32), [1, 0]],
#  [array([58., 57., 59., ..., 50., 50., 50.], dtype=float32), [1, 0]],
#  [array([55., 56., 57., ..., 52., 52., 52.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([95., 95., 95., ..., 64., 67., 77.], dtype=float32), [1, 0]],
#  [array([ 71.,  70.,  68., ..., 100., 107., 109.], dtype=float32), [1, 0]],
#  [array([11., 12., 11., ..., 11., 10., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ...,  9.,  9., 10.], dtype=float32), [1, 0]],
#  [array([ 9., 10.,  9., ...,  9.,  9., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 11., ..., 10., 11., 11.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([29., 33., 33., ..., 53., 91., 99.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([231., 230., 229., ..., 170., 171., 174.], dtype=float32), [1, 0]],
#  [array([81., 82., 82., ..., 61., 63., 66.], dtype=float32), [1, 0]],
#  [array([58., 58., 58., ..., 58., 59., 59.], dtype=float32), [1, 0]],
#  [array([51., 52., 52., ..., 57., 56., 55.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 74., 102.,  93., ...,   0.,   0.,   0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([68., 62., 60., ..., 40., 48., 71.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11.,  9.,  8., ..., 11., 10., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([ 8.,  8.,  8., ..., 10.,  9., 10.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ...,  9.,  8.,  8.], dtype=float32), [1, 0]],
#  [array([9., 9., 8., ..., 3., 3., 3.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 88., 90., 19.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([7., 7., 8., ..., 8., 8., 8.], dtype=float32), [1, 0]],
#  [array([140., 132., 126., ...,   4.,   4.,   4.], dtype=float32), [1, 0]],
#  [array([54., 54., 55., ..., 47., 48., 49.], dtype=float32), [1, 0]],
#  [array([55., 55., 56., ..., 48., 48., 50.], dtype=float32), [1, 0]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [1, 0]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 10., 11.], dtype=float32), [1, 0]],
#  [array([8., 7., 8., ..., 8., 7., 7.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 86., 103.,  85., ...,  29.,  56.,  48.], dtype=float32), [1, 0]],
#  [array([114., 105.,  96., ..., 114., 114., 113.], dtype=float32), [1, 0]],
#  [array([47., 47., 48., ..., 47., 48., 49.], dtype=float32), [1, 0]],
#  [array([28., 29., 42., ...,  7.,  7.,  7.], dtype=float32), [1, 0]],
#  [array([60., 60., 59., ..., 64., 65., 65.], dtype=float32), [1, 0]],
#  [array([53., 53., 52., ..., 52., 53., 54.], dtype=float32), [1, 0]],
#  [array([52., 53., 52., ..., 20., 20., 21.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([10.,  9., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([51., 52., 50., ..., 51., 51., 53.], dtype=float32), [1, 0]],
#  [array([50., 50., 51., ..., 57., 55., 54.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([  0.,   0.,   0., ..., 105., 108.,  92.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11.,  9.,  9., ..., 81., 81., 83.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  9., ..., 10.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([109., 110., 110., ...,  62.,  62.,  62.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 82., 80., 72.], dtype=float32), [1, 0]],
#  [array([10., 11., 11., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([5., 5., 5., ..., 4., 4., 4.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([108., 109., 108., ..., 112., 125., 153.], dtype=float32), [1, 0]],
#  [array([126., 130., 132., ...,  33.,  33.,  34.], dtype=float32), [1, 0]],
#  [array([126., 134., 141., ...,  44.,  45.,  46.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([214., 214., 214., ..., 203., 202., 201.], dtype=float32), [1, 0]],
#  [array([11., 11., 11., ..., 11., 10., 11.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([10., 10., 11., ..., 12., 13., 10.], dtype=float32), [1, 0]],
#  [array([ 9.,  9., 10., ...,  7.,  8.,  8.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  9., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([ 9., 10., 10., ...,  9.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([ 38.,  38.,  38., ..., 117., 114., 121.], dtype=float32), [1, 0]],
#  [array([ 94., 105., 104., ...,  59.,  57.,  63.], dtype=float32), [1, 0]],
#  [array([146., 146., 149., ...,  90.,  89.,  99.], dtype=float32), [1, 0]],
#  [array([124., 131., 114., ...,  96.,  97., 105.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([54., 77., 68., ...,  0.,  0.,  0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 71.,  68.,  65., ..., 102., 104., 107.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([38., 36., 36., ..., 37., 37., 38.], dtype=float32), [1, 0]],
#  [array([27., 28., 28., ..., 29., 30., 29.], dtype=float32), [1, 0]],
#  [array([51., 50., 51., ..., 54., 53., 54.], dtype=float32), [1, 0]],
#  [array([55., 55., 54., ..., 55., 55., 55.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([3., 4., 3., ..., 4., 4., 4.], dtype=float32), [1, 0]],
#  [array([252., 252., 251., ..., 251., 251., 250.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 82., 107., 103., ...,  37.,  52.,  60.], dtype=float32), [1, 0]],
#  [array([ 95.,  96.,  96., ..., 101.,  99.,  96.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([118., 118., 117., ...,  90.,  90.,  90.], dtype=float32), [1, 0]],
#  [array([255., 244., 129., ..., 110., 109., 113.], dtype=float32), [1, 0]],
#  [array([10.,  9.,  9., ...,  9.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ...,  9.,  9., 10.], dtype=float32), [1, 0]],
#  [array([15., 11., 11., ..., 31., 27., 22.], dtype=float32), [1, 0]],
#  [array([174., 181., 177., ...,  55.,  56.,  57.], dtype=float32), [1, 0]],
#  [array([56., 57., 58., ..., 51., 50., 50.], dtype=float32), [1, 0]],
#  [array([2., 2., 2., ..., 8., 8., 7.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [1, 0]],
#  [array([117., 113., 118., ..., 124., 123., 123.], dtype=float32), [1, 0]],
#  [array([52., 47., 47., ..., 36., 35., 35.], dtype=float32), [1, 0]],
#  [array([136., 135., 134., ..., 187., 190., 197.], dtype=float32), [1, 0]],
#  [array([ 94.,  90.,  91., ..., 181., 181., 181.], dtype=float32), [1, 0]],
#  [array([ 9.,  9.,  9., ..., 10., 11., 11.], dtype=float32), [1, 0]],
#  [array([ 2.,  2.,  2., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([40., 26.,  0., ..., 42., 44., 44.], dtype=float32), [1, 0]],
#  [array([49., 53., 42., ..., 23., 20., 19.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([11., 10., 10., ..., 10., 10., 11.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 39.,  37.,  37., ...,  90.,  96., 101.], dtype=float32), [1, 0]],
#  [array([ 66.,  65.,  65., ..., 134., 139., 145.], dtype=float32), [1, 0]],
#  [array([102., 102., 101., ...,  90.,  90.,  93.], dtype=float32), [1, 0]],
#  [array([80., 99., 94., ..., 74., 79., 63.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([11., 11., 10., ...,  9., 10., 10.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([88., 88., 87., ...,  0.,  0.,  0.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 66., 73., 40.], dtype=float32), [1, 0]],
#  [array([10., 11., 10., ...,  9.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ...,  9.,  9.,  9.], dtype=float32), [1, 0]],
#  [array([ 0.,  0.,  0., ..., 66., 70., 74.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 0.,  1.,  0., ..., 59., 74., 84.], dtype=float32), [1, 0]],
#  [array([244., 243., 242., ..., 191., 227., 237.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ...,  6.,  6.,  6.], dtype=float32), [1, 0]],
#  [array([11., 11., 11., ..., 36., 48., 39.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([82., 82., 81., ..., 42., 46., 49.], dtype=float32), [1, 0]],
#  [array([ 86., 107., 103., ...,  71.,  70.,  55.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([45., 45., 44., ..., 30., 29., 30.], dtype=float32), [1, 0]],
#  [array([73., 38., 26., ..., 38., 37., 38.], dtype=float32), [1, 0]],
#  [array([41., 39., 40., ..., 41., 41., 42.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([ 75., 100.,  74., ...,  13.,  24.,  37.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([198., 200., 200., ..., 199., 198., 196.], dtype=float32), [1, 0]],
#  [array([54., 53., 52., ..., 49., 50., 50.], dtype=float32), [1, 0]],
#  [array([35., 34., 34., ...,  3.,  4.,  4.], dtype=float32), [1, 0]],
#  [array([10., 10., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([6., 6., 6., ..., 7., 7., 7.], dtype=float32), [1, 0]],
#  [array([9., 9., 9., ..., 9., 9., 9.], dtype=float32), [1, 0]],
#  [array([ 9.,  9., 10., ..., 10., 10., 10.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([122., 122., 122., ...,  56.,  56.,  55.], dtype=float32), [1, 0]],
#  [array([55., 55., 55., ..., 54., 54., 56.], dtype=float32), [1, 0]],
#  [array([58., 58., 58., ..., 55., 56., 57.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([180., 179., 179., ...,   0.,   0.,   0.], dtype=float32), [1, 0]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [1, 0]],
#  [array([247., 247., 247., ..., 249., 250., 251.], dtype=float32), [0, 1]],
#  [array([8., 8., 8., ..., 5., 5., 5.], dtype=float32), [0, 1]],
#  [array([69., 66., 67., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([240., 220., 176., ..., 197., 212., 210.], dtype=float32), [0, 1]],
#  [array([211., 198., 178., ..., 169., 216., 246.], dtype=float32), [0, 1]],
#  [array([252., 254., 237., ..., 199., 216., 244.], dtype=float32), [0, 1]],
#  [array([ 36.,  36.,  36., ..., 147., 140., 143.], dtype=float32), [0, 1]],
#  [array([35., 36., 37., ..., 30., 31., 32.], dtype=float32), [0, 1]],
#  [array([ 74., 102.,  83., ...,  64.,  76.,  57.], dtype=float32), [0, 1]],
#  [array([ 77., 114., 102., ...,  63.,  76.,  53.], dtype=float32), [0, 1]],
#  [array([74., 73., 73., ..., 33., 33., 35.], dtype=float32), [0, 1]],
#  [array([65., 64., 63., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([73., 71., 69., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([69., 68., 67., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([47., 47., 47., ..., 47., 47., 47.], dtype=float32), [0, 1]],
#  [array([47., 47., 47., ..., 47., 47., 47.], dtype=float32), [0, 1]],
#  [array([31., 31., 28., ..., 28., 28., 30.], dtype=float32), [0, 1]],
#  [array([37., 37., 38., ..., 35., 34., 35.], dtype=float32), [0, 1]],
#  [array([85., 16., 18., ..., 66., 70., 90.], dtype=float32), [0, 1]],
#  [array([57., 57., 57., ..., 55., 54., 53.], dtype=float32), [0, 1]],
#  [array([53., 52., 53., ..., 57., 57., 56.], dtype=float32), [0, 1]],
#  [array([54., 54., 54., ..., 56., 55., 56.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 74., 75., 82.], dtype=float32), [0, 1]],
#  [array([ 6.,  5.,  5., ..., 77., 78., 77.], dtype=float32), [0, 1]],
#  [array([76., 76., 75., ..., 37., 37., 38.], dtype=float32), [0, 1]],
#  [array([19., 21., 17., ..., 55., 55., 57.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([106.,  98.,  89., ...,   4.,   3.,   4.], dtype=float32), [0, 1]],
#  [array([57., 43., 45., ..., 49., 47., 48.], dtype=float32), [0, 1]],
#  [array([63., 45., 45., ..., 46., 46., 46.], dtype=float32), [0, 1]],
#  [array([29., 29., 30., ..., 28., 30., 28.], dtype=float32), [0, 1]],
#  [array([33., 33., 33., ..., 34., 32., 33.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([61., 59., 61., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 12.,  9.,  9.], dtype=float32), [0, 1]],
#  [array([11., 10., 10., ...,  8.,  9.,  9.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([81., 78., 81., ..., 40., 73., 60.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([61., 61., 62., ..., 56., 56., 55.], dtype=float32), [0, 1]],
#  [array([211., 201., 203., ..., 120., 120., 123.], dtype=float32), [0, 1]],
#  [array([38., 38., 38., ...,  6.,  6.,  6.], dtype=float32), [0, 1]],
#  [array([35., 35., 35., ...,  0., 17., 28.], dtype=float32), [0, 1]],
#  [array([5., 5., 5., ..., 5., 5., 5.], dtype=float32), [0, 1]],
#  [array([8., 8., 8., ..., 8., 8., 8.], dtype=float32), [0, 1]],
#  [array([47., 46., 43., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([48., 48., 46., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([194., 200., 199., ..., 198., 201., 202.], dtype=float32), [0, 1]],
#  [array([195., 197., 196., ..., 196., 196., 196.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 6., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([ 92., 105., 102., ...,   0.,   0.,   0.], dtype=float32), [0, 1]],
#  [array([106., 104., 103., ...,  54.,  58.,  62.], dtype=float32), [0, 1]],
#  [array([157., 156., 152., ...,  37.,  37.,  36.], dtype=float32), [0, 1]],
#  [array([158., 151., 141., ...,  30.,  29.,  30.], dtype=float32), [0, 1]],
#  [array([58., 56., 55., ..., 38., 38., 39.], dtype=float32), [0, 1]],
#  [array([52., 35., 37., ..., 39., 39., 39.], dtype=float32), [0, 1]],
#  [array([8., 8., 8., ..., 8., 8., 8.], dtype=float32), [0, 1]],
#  [array([58., 75., 69., ..., 39., 39., 39.], dtype=float32), [0, 1]],
#  [array([44., 55., 51., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([217., 217., 217., ..., 206., 242., 229.], dtype=float32), [0, 1]],
#  [array([217., 217., 217., ..., 217., 217., 217.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([ 99., 110., 106., ...,  40.,  40.,  39.], dtype=float32), [0, 1]],
#  [array([ 94., 107., 104., ...,  37.,  38.,  32.], dtype=float32), [0, 1]],
#  [array([46., 47., 47., ..., 83., 83., 83.], dtype=float32), [0, 1]],
#  [array([90., 89., 86., ...,  9.,  9.,  9.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([225., 201., 200., ..., 132., 130., 141.], dtype=float32), [0, 1]],
#  [array([47., 46., 46., ..., 42., 46., 67.], dtype=float32), [0, 1]],
#  [array([50., 49., 49., ..., 49., 50., 64.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([ 5.,  5.,  4., ..., 97., 96., 97.], dtype=float32), [0, 1]],
#  [array([111., 109., 108., ...,  10.,  10.,  10.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([ 70.,  70.,  70., ..., 111., 111., 113.], dtype=float32), [0, 1]],
#  [array([ 0.,  0.,  0., ..., 80., 86., 68.], dtype=float32), [0, 1]],
#  [array([102., 125., 119., ...,  61.,  78.,  79.], dtype=float32), [0, 1]],
#  [array([59., 57., 57., ..., 59., 59., 58.], dtype=float32), [0, 1]],
#  [array([58., 54., 56., ..., 57., 56., 55.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([65., 71., 71., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([8., 7., 7., ..., 7., 7., 8.], dtype=float32), [0, 1]],
# ...
#  [array([27., 26., 26., ..., 27., 27., 26.], dtype=float32), [0, 1]],
#  [array([37., 36., 36., ..., 38., 39., 38.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([125., 125., 125., ...,   0.,   1.,  32.], dtype=float32), [0, 1]],
#  [array([101., 101., 100., ...,  91.,  96.,  98.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([98., 94., 90., ..., 47., 47., 48.], dtype=float32), [0, 1]],
#  [array([107., 107., 107., ...,  37.,  35.,  35.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 10., 10., 10.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 11., 11., 11.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 10., 10.,  9.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ...,  9.,  9.,  9.], dtype=float32), [0, 1]],
#  [array([60., 60., 60., ..., 59., 60., 60.], dtype=float32), [0, 1]],
#  [array([59., 59., 59., ..., 59., 59., 59.], dtype=float32), [0, 1]],
#  [array([131., 130., 131., ...,  46.,  43.,  55.], dtype=float32), [0, 1]],
#  [array([60., 42., 46., ..., 52., 52., 51.], dtype=float32), [0, 1]],
#  [array([118., 117., 117., ...,   0.,   0.,   0.], dtype=float32), [0, 1]],
#  [array([119., 119., 118., ...,   0.,   0.,   0.], dtype=float32), [0, 1]],
#  [array([192., 201., 201., ...,  88.,  89.,  85.], dtype=float32), [0, 1]],
#  [array([ 18., 106., 113., ...,  87.,  91.,  91.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([13.,  9.,  9., ..., 36., 35., 36.], dtype=float32), [0, 1]],
#  [array([12., 12., 12., ..., 35., 35., 36.], dtype=float32), [0, 1]],
#  [array([ 0.,  0.,  0., ..., 16., 16., 16.], dtype=float32), [0, 1]],
#  [array([ 0., 29., 69., ..., 31., 30., 24.], dtype=float32), [0, 1]],
#  [array([  9.,   8.,   8., ..., 122., 123., 124.], dtype=float32), [0, 1]],
#  [array([10.,  9.,  9., ..., 10.,  9., 10.], dtype=float32), [0, 1]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [0, 1]],
#  [array([178., 164., 166., ...,   2.,   2.,   2.], dtype=float32), [0, 1]],
#  [array([5., 5., 5., ..., 5., 6., 6.], dtype=float32), [0, 1]],
#  [array([ 8.,  8.,  8., ..., 33., 29., 31.], dtype=float32), [0, 1]],
#  [array([ 9.,  9.,  9., ...,  9.,  9., 10.], dtype=float32), [0, 1]],
#  [array([36., 38., 39., ..., 37., 38., 36.], dtype=float32), [0, 1]],
#  [array([34., 37., 66., ..., 35., 34., 33.], dtype=float32), [0, 1]],
#  [array([10., 10., 11., ..., 10., 10., 10.], dtype=float32), [0, 1]],
#  [array([11., 10., 10., ...,  9., 10., 10.], dtype=float32), [0, 1]],
#  [array([181., 181., 182., ..., 176., 176., 175.], dtype=float32), [0, 1]],
#  [array([218., 243., 213., ..., 199., 205., 212.], dtype=float32), [0, 1]],
#  [array([121., 120., 118., ..., 167., 170., 172.], dtype=float32), [0, 1]],
#  [array([57., 56., 57., ..., 58., 59., 58.], dtype=float32), [0, 1]],
#  [array([55., 57., 55., ..., 56., 54., 55.], dtype=float32), [0, 1]],
#  [array([37., 36., 36., ..., 43., 43., 42.], dtype=float32), [0, 1]],
#  [array([45., 45., 44., ..., 35., 35., 38.], dtype=float32), [0, 1]],
#  [array([102.,  16.,  21., ...,  78.,  77.,  78.], dtype=float32), [0, 1]],
#  [array([46., 45., 45., ..., 52., 53., 53.], dtype=float32), [0, 1]],
#  [array([49., 48., 48., ..., 52., 51., 51.], dtype=float32), [0, 1]],
#  [array([41., 35., 37., ..., 36., 36., 37.], dtype=float32), [0, 1]],
#  [array([18., 16., 16., ..., 18., 18., 18.], dtype=float32), [0, 1]],
#  [array([148., 145., 148., ...,  48.,  47.,  48.], dtype=float32), [0, 1]],
#  [array([50., 48., 48., ..., 41., 41., 42.], dtype=float32), [0, 1]],
#  [array([ 65.,  53.,  49., ..., 127., 128., 130.], dtype=float32), [0, 1]],
#  [array([175., 187., 202., ..., 216., 216., 213.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([43., 42., 43., ..., 50., 50., 51.], dtype=float32), [0, 1]],
#  [array([47., 47., 46., ..., 49., 48., 49.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([6., 6., 7., ..., 7., 7., 6.], dtype=float32), [0, 1]],
#  [array([9., 9., 9., ..., 9., 9., 9.], dtype=float32), [0, 1]],
#  [array([17., 19., 20., ...,  9., 10.,  8.], dtype=float32), [0, 1]],
#  [array([222., 221., 221., ..., 244., 243., 244.], dtype=float32), [0, 1]],
#  [array([14., 13., 14., ...,  3.,  2.,  2.], dtype=float32), [0, 1]],
#  [array([203., 202., 202., ..., 200., 201., 201.], dtype=float32), [0, 1]],
#  [array([ 97.,  96.,  95., ..., 116., 117., 117.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([122., 105., 113., ...,  72.,  73.,  75.], dtype=float32), [0, 1]],
#  [array([10., 10., 11., ..., 10., 10., 11.], dtype=float32), [0, 1]],
#  [array([6., 5., 5., ..., 6., 5., 5.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([120., 121., 121., ..., 117., 117., 117.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([18., 21., 20., ..., 33., 30., 31.], dtype=float32), [0, 1]],
#  [array([31., 31., 30., ..., 68., 59., 49.], dtype=float32), [0, 1]],
#  [array([45., 44., 45., ..., 48., 49., 48.], dtype=float32), [0, 1]],
#  [array([87., 87., 87., ..., 46., 46., 45.], dtype=float32), [0, 1]],
#  [array([61., 48., 49., ..., 50., 50., 50.], dtype=float32), [0, 1]],
#  [array([52., 51., 53., ..., 48., 48., 61.], dtype=float32), [0, 1]],
#  [array([158., 150., 150., ...,  31.,  29.,  30.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 2., 1., 1.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([192., 193., 194., ..., 194., 194., 193.], dtype=float32), [0, 1]],
#  [array([61., 60., 61., ..., 62., 62., 63.], dtype=float32), [0, 1]],
#  [array([48., 47., 47., ..., 80., 76., 75.], dtype=float32), [0, 1]],
#  [array([133., 131., 129., ..., 109., 109., 107.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([1., 1., 2., ..., 2., 2., 2.], dtype=float32), [0, 1]],
#  [array([253., 253., 253., ..., 253., 253., 253.], dtype=float32), [0, 1]],
#  [array([51., 51., 51., ..., 50., 49., 49.], dtype=float32), [0, 1]],
#  [array([60., 57., 57., ..., 53., 53., 53.], dtype=float32), [0, 1]],
#  [array([11., 11., 12., ..., 11., 10., 10.], dtype=float32), [0, 1]],
#  [array([10., 10.,  9., ...,  9.,  8.,  9.], dtype=float32), [0, 1]],
#  [array([34., 37., 38., ..., 36., 33., 36.], dtype=float32), [0, 1]],
#  [array([35., 35., 35., ..., 35., 37., 35.], dtype=float32), [0, 1]],
#  [array([5., 4., 5., ..., 4., 5., 5.], dtype=float32), [0, 1]],
#  [array([5., 5., 5., ..., 5., 5., 5.], dtype=float32), [0, 1]],
#  [array([50., 50., 52., ..., 40., 40., 40.], dtype=float32), [0, 1]],
#  [array([40., 40., 40., ..., 40., 40., 40.], dtype=float32), [0, 1]],
#  [array([86., 88., 82., ..., 64., 58., 61.], dtype=float32), [0, 1]],
#  [array([11., 10., 11., ...,  7.,  7.,  9.], dtype=float32), [0, 1]],
#  [array([ 67.,  52.,  47., ..., 119., 119., 119.], dtype=float32), [0, 1]],
#  [array([ 90.,  68.,  62., ..., 118., 119., 119.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([86., 90., 79., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([83., 79., 80., ..., 33., 32., 33.], dtype=float32), [0, 1]],
#  [array([31., 32., 32., ..., 31., 31., 32.], dtype=float32), [0, 1]],
#  [array([106., 113., 123., ...,  97., 101., 101.], dtype=float32), [0, 1]],
#  [array([116.,  96.,  68., ..., 104., 106., 107.], dtype=float32), [0, 1]],
#  [array([ 8.,  8.,  8., ..., 80., 78., 80.], dtype=float32), [0, 1]],
#  [array([ 5.,  6.,  7., ...,  9.,  9., 10.], dtype=float32), [0, 1]],
#  [array([179., 167., 171., ...,  57.,  58.,  58.], dtype=float32), [0, 1]],
#  [array([42., 40., 39., ..., 55., 54., 54.], dtype=float32), [0, 1]],
#  [array([203., 205., 205., ..., 197., 197., 197.], dtype=float32), [0, 1]],
#  [array([119., 120., 119., ...,  51.,  47.,  46.], dtype=float32), [0, 1]],
#  [array([10.,  9.,  9., ..., 11., 10., 10.], dtype=float32), [0, 1]],
#  [array([ 8.,  8.,  8., ..., 10.,  9.,  9.], dtype=float32), [0, 1]],
#  [array([4., 4., 3., ..., 3., 4., 4.], dtype=float32), [0, 1]],
#  [array([10., 11., 11., ..., 10., 10., 10.], dtype=float32), [0, 1]],
#  [array([39., 37., 37., ..., 34., 35., 35.], dtype=float32), [0, 1]],
#  [array([46., 44., 44., ..., 42., 41., 41.], dtype=float32), [0, 1]],
#  [array([7., 6., 6., ..., 7., 8., 7.], dtype=float32), [0, 1]],
#  [array([ 9.,  9.,  9., ..., 10., 10., 10.], dtype=float32), [0, 1]],
#  [array([214., 114., 114., ...,  59.,  59.,  60.], dtype=float32), [0, 1]],
#  [array([57., 57., 57., ..., 46., 41., 60.], dtype=float32), [0, 1]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [0, 1]],
#  [array([2., 2., 2., ..., 2., 2., 2.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([ 92.,  93.,  90., ..., 128., 128., 118.], dtype=float32), [0, 1]],
#  [array([24., 36., 51., ..., 13., 13., 13.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 10., 10., 11.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ..., 10.,  9., 11.], dtype=float32), [0, 1]],
#  [array([34., 34., 35., ..., 35., 36., 35.], dtype=float32), [0, 1]],
#  [array([29., 29., 29., ..., 32., 32., 32.], dtype=float32), [0, 1]],
#  [array([58., 56., 56., ..., 50., 50., 50.], dtype=float32), [0, 1]],
#  [array([53., 53., 52., ..., 93., 94., 97.], dtype=float32), [0, 1]],
#  [array([59., 57., 58., ..., 53., 53., 53.], dtype=float32), [0, 1]],
#  [array([49., 48., 47., ..., 23., 26., 29.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([140., 132., 129., ...,   3.,   4.,   4.], dtype=float32), [0, 1]],
#  [array([10.,  9., 10., ..., 10., 10., 10.], dtype=float32), [0, 1]],
#  [array([8., 9., 9., ..., 7., 7., 7.], dtype=float32), [0, 1]],
#  [array([84., 84., 83., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([91., 91., 89., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([20., 19., 20., ..., 23., 24., 24.], dtype=float32), [0, 1]],
#  [array([19., 18., 19., ..., 21., 22., 22.], dtype=float32), [0, 1]],
#  [array([119., 119., 118., ...,   7.,  12., 139.], dtype=float32), [0, 1]],
#  [array([64., 47., 47., ..., 48., 48., 48.], dtype=float32), [0, 1]],
#  [array([59., 59., 59., ..., 59., 58., 59.], dtype=float32), [0, 1]],
#  [array([196., 196., 196., ..., 195., 195., 195.], dtype=float32), [0, 1]],
#  [array([59., 57., 58., ..., 55., 55., 54.], dtype=float32), [0, 1]],
#  [array([55., 54., 54., ..., 49., 50., 50.], dtype=float32), [0, 1]],
#  [array([52., 50., 53., ..., 54., 54., 55.], dtype=float32), [0, 1]],
#  [array([48., 47., 48., ..., 53., 52., 57.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([65., 65., 70., ..., 92., 93., 93.], dtype=float32), [0, 1]],
#  [array([54., 55., 56., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([62., 42., 39., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([31., 28., 29., ..., 30., 31., 33.], dtype=float32), [0, 1]],
#  [array([40., 39., 41., ..., 40., 42., 47.], dtype=float32), [0, 1]],
#  [array([188., 118., 124., ...,  51.,  52.,  51.], dtype=float32), [0, 1]],
#  [array([61., 51., 50., ..., 47., 47., 48.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([37., 37., 37., ..., 20., 20., 21.], dtype=float32), [0, 1]],
#  [array([30., 31., 31., ..., 28., 29., 28.], dtype=float32), [0, 1]],
#  [array([36., 35., 37., ..., 34., 37., 37.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([52., 52., 51., ..., 44., 44., 43.], dtype=float32), [0, 1]],
#  [array([54., 55., 54., ..., 50., 49., 49.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([83., 81., 79., ..., 78., 78., 78.], dtype=float32), [0, 1]],
#  [array([224., 228., 231., ...,   4.,   4.,   5.], dtype=float32), [0, 1]],
#  [array([216., 213., 200., ...,   5.,   5.,   6.], dtype=float32), [0, 1]],
#  [array([5., 6., 5., ..., 5., 5., 5.], dtype=float32), [0, 1]],
#  [array([4., 6., 8., ..., 9., 8., 8.], dtype=float32), [0, 1]],
#  [array([ 56.,  56.,  56., ..., 134., 130., 132.], dtype=float32), [0, 1]],
#  [array([ 66.,  66.,  66., ..., 164., 162., 161.], dtype=float32), [0, 1]],
#  [array([ 9.,  9.,  9., ..., 11., 11., 11.], dtype=float32), [0, 1]],
#  [array([9., 8., 8., ..., 8., 8., 8.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([72., 74., 75., ...,  0.,  0.,  0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([48., 49., 48., ..., 45., 45., 46.], dtype=float32), [0, 1]],
#  [array([44., 45., 45., ..., 49., 48., 50.], dtype=float32), [0, 1]],
#  [array([57., 58., 58., ..., 54., 52., 55.], dtype=float32), [0, 1]],
#  [array([148., 148., 148., ...,  43.,  43.,  43.], dtype=float32), [0, 1]],
#  [array([54., 43., 47., ..., 59., 59., 59.], dtype=float32), [0, 1]],
#  [array([121., 117., 127., ...,  11.,  11.,  10.], dtype=float32), [0, 1]],
#  [array([11., 10., 11., ..., 11., 11., 10.], dtype=float32), [0, 1]],
#  [array([  8.,   8.,   8., ...,  92., 146., 150.], dtype=float32), [0, 1]],
#  [array([167., 128., 131., ...,  32.,  32.,  32.], dtype=float32), [0, 1]],
#  [array([25., 24., 25., ..., 37., 33., 29.], dtype=float32), [0, 1]],
#  [array([10.,  9., 10., ...,  9.,  8.,  9.], dtype=float32), [0, 1]],
#  [array([10., 10., 10., ...,  9.,  8.,  9.], dtype=float32), [0, 1]],
#  [array([34., 34., 35., ..., 28., 29., 28.], dtype=float32), [0, 1]],
#  [array([38., 35., 36., ..., 36., 36., 35.], dtype=float32), [0, 1]],
#  [array([41., 38., 37., ..., 81., 75., 76.], dtype=float32), [0, 1]],
#  [array([44., 41., 41., ..., 95., 95., 97.], dtype=float32), [0, 1]],
#  [array([ 97.,  93.,  91., ..., 141., 132., 119.], dtype=float32), [0, 1]],
#  [array([26., 21., 22., ..., 88., 88., 90.], dtype=float32), [0, 1]],
#  [array([58., 46., 48., ..., 38., 39., 39.], dtype=float32), [0, 1]],
#  [array([58., 37., 40., ..., 32., 34., 33.], dtype=float32), [0, 1]],
#  [array([94., 92., 92., ..., 26., 25., 26.], dtype=float32), [0, 1]],
#  [array([80., 88., 86., ..., 27., 28., 25.], dtype=float32), [0, 1]],
#  [array([28., 28., 28., ..., 30., 29., 30.], dtype=float32), [0, 1]],
#  [array([28., 30., 29., ..., 31., 31., 31.], dtype=float32), [0, 1]],
#  [array([78., 84., 50., ..., 85., 85., 86.], dtype=float32), [0, 1]],
#  [array([134., 129., 127., ...,  49.,  48.,  49.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  [array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), [0, 1]],
#  ...]

# %%
test_data = []

def create_test_data():
    for category in CATEGORIES:  # do dogs and cats

        path = os.path.join(DATADIR1,category)  # create path to dogs and cats
        class_num = CATEGORIES.index(category)  # get the classification  (0 or a 1). 0=dog 1=cat
        if ((class_num)==1):
            t=[0,1]
        else:
            t=[1,0]
                
        for img in os.listdir(path):  # iterate over each image per dogs and cats
            im = Image.open(os.path.join(path,img))
            enhancer = ImageEnhance.Sharpness(im)
            img2=enhancer.enhance(2)
            img2 = img2.resize((200,200), Image.ANTIALIAS) 
            img2=img2.convert("L")
            img2 = image.img_to_array(img2)
            new_array = np.array(img2).reshape(40000)


            #new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            # resize to normalize data size
            #new_array = np.array(img2).reshape(40000)
            test_data.append([new_array,t ])  # add this to our training_data
        
            #except OSError as e:
            #    print("OSErrroBad img most likely", e, os.path.join(path,img))
            #except Exception as e:
            #    print("general exception", e, os.path.join(path,img))



create_test_data()

print(len(test_data))
# Out:
# 288

# %%
random.shuffle(training_data)

# %%
import random
#random.shuffle(test_data)
random.shuffle(training_data)

# %%
def next_batch(batch_size,training_data,count):
    X = []
    y = []
    for sample in training_data[count*10:(batch_size+(count*10))]:
        X.append(sample[0])
        y.append(sample[1])    
    return X, y

# %%
tf.reset_default_graph()

# %%
train(training_data,test_data)
# Out:
# outputs:  Tensor("predict_actions/policy_network/policy_network/strided_slice:0", shape=(?, 1, 400), dtype=float32)
# outputs:  Tensor("predict_actions/policy_network/policy_network/strided_slice_1:0", shape=(?, 1, 400), dtype=float32)
# action: Tensor("predict_actions/predicted_action:0", shape=(?, 1, 400), dtype=int32)
# outputs:  Tensor("compute_gradients/policy_network/policy_network/strided_slice:0", shape=(?, 1, 400), dtype=float32)
# self.logprobs Tensor("compute_gradients/policy_network/policy_network/strided_slice_1:0", shape=(?, 1, 400), dtype=float32)
# WARNING:tensorflow:From <ipython-input-4-a2726ed950a6>:60: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# ca: [[[ 5  5  5  5  5  5  5  5  5  6 11  5  5  5  5  9  6  6  5  5  5  6  5
#     5  5  5  5  9  5 12  5  5  5  5 10  8  5  5  5  8  5  5 12  5  5  5
#     5  5  7  5  5  9  5  5 12  5  5  5  6  5  5  5 12  5  5  5  7  7  5
#     5  6  5  7  5  5  5  6  5  5  5  6  5  5  5  6  5  5  5 12  5  5 12
#     5  5  5 11  5  5  5  5  6  5  8  5  5  5  6  5  5  5  5  5  6  5  6
#     5  5  8  5 11  9  5  5  5  5 11  6  7  5  5  5  5  5 11  5  5  5  5
#     5 11 10  5 11  5  5  5  5  5  5  5  5  9  5  7  5  5  5  5  5  5  5
#     5  6  5  6  5  6  5  5  5  5  5  5 11  5  5 11  5  8  5  5  8  6  5
#     5  5  5  5  5  9  6  7  6 13 10  5  8  5  5  6  5  5 10 10  5  5  5
#     8 11  5  5  5  6  5 11  5  6 10  5  5  5  5  5  9  5  5  6  5  8  8
#     6  5  5  5  6  5  5  8  5  5  5 10  5  5  5  5  7  5 12 12  5  5  5
#     5  5  5  6  5 12  5  5  5  5  9  5  5  8 11  5 10  6  5  6  5 12 12
#     5  5  5  5  5  5  5 12  5  5  5  5  6  5  5  6 12  6  5  5 11  8  8
#     5  5  5  5  5  7  5  5  9  5  5  5  6  5  5  7  5  5  5  5  5  5 11
#     5  6  5  6  5  5  5  6  5  8  5  5 10  5  7 12  5  6  5  5  6  5  5
#     7  6  5  5  5  5  5 12  6  8  5  5  8  5  5  5  5  5 10  5 11  5  5
#     6 10  5  5  5  5  5  5 10  5  6  5  5  5  5  7  7  5 12 11  5  5 10
#     5  6  6  5  7  5  5  5  5]]]
